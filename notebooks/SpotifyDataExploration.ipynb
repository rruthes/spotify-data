# %% [markdown]
# Importando as dependências.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %% [markdown]
# Transformando o conjunto geral de dados em um data set e limpando os dados.

# %%
df = pd.read_csv('../data/raw/Spotify Most Streamed Songs.csv')
df.dropna()
df = df.drop(columns=['cover_url', 'key', 'in_shazam_charts', 'in_deezer_charts', 'in_deezer_playlists', 'mode'])
df.head(50)
# Out:
#                                            track_name  \
# 0                 Seven (feat. Latto) (Explicit Ver.)
# 1                                                LALA
# 2                                             vampire
# 3                                        Cruel Summer
# 4                                      WHERE SHE GOES
# 5                                            Sprinter
# 6                                     Ella Baila Sola
# 7                                            Columbia
# 8                                            fukumean
# 9                                     La Bebe - Remix
# 10                                          un x100to
# 11                                          Super Shy
# 12                                            Flowers
# 13                                           Daylight
# 14                                          As It Was
# 15                                          Kill Bill
# ...

# %% [markdown]
# Listando as músicas com o maior número de streams, em ordem decrescente.

# %%
df = df[df['track_name'] != 'Love Grows (Where My Rosemary Goes)']
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
df_sorted = df.sort_values(by='streams', ascending=False)
p_streams = df_sorted.head(50)
p_streams.to_csv('../data/processed/top50_streams.csv', index=False)
p_streams.head(10)
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# 162                                      One Dance
# 84                       STAY (with Justin Bieber)
# 140                                       Believer
# 725                                         Closer
# 48                                         Starboy
#
#                    artist(s)_name  artist_count  released_year  \
# 55                     The Weeknd             1           2019
# 179                    Ed Sheeran             1           2017
# 86                  Lewis Capaldi             1           2018
# 620                   Tones and I             1           2019
# 41          Post Malone, Swae Lee             2           2018
# ...

# %% [markdown]
# Listando as músicas que mais estão em playlists no Spotify.

# %%
df['in_spotify_playlists'] = pd.to_numeric(df['in_spotify_playlists'], errors='coerce')
df_sorted = df.sort_values(by='in_spotify_playlists', ascending=False)
p_playlists = df_sorted.head(50)
p_playlists.to_csv('../data/processed/top50_playlists.csv', index=False)
p_playlists.head(10)
# Out:
#                                     track_name  \
# 757                     Get Lucky - Radio Edit
# 630                             Mr. Brightside
# 720                    Wake Me Up - Radio Edit
# 624  Smells Like Teen Spirit - Remastered 2021
# 199                                 Take On Me
# 55                             Blinding Lights
# 162                                  One Dance
# 727               Somebody That I Used To Know
# 114          Everybody Wants To Rule The World
# 871                        Sweet Child O' Mine
#
#                                  artist(s)_name  artist_count  released_year  \
# 757  Pharrell Williams, Nile Rodgers, Daft Punk             3           2013
# 630                                 The Killers             1           2003
# 720                                      Avicii             1           2013
# 624                                     Nirvana             1           1991
# ...

# %% [markdown]
# Listando as que mais estão em playlists do Apple Music.

# %%
df['in_apple_playlists'] = pd.to_numeric(df['in_apple_playlists'], errors='coerce')
df_sorted = df.sort_values(by='in_apple_playlists', ascending=False)
p_apple_playlists = df_sorted.head(50)
p_apple_playlists.to_csv('../data/processed/top50_apple_playlists.csv', index=False)
p_apple_playlists.head(10)
# Out:
#                     track_name                artist(s)_name  artist_count  \
# 55             Blinding Lights                    The Weeknd             1
# 403   One Kiss (with Dua Lipa)       Calvin Harris, Dua Lipa             2
# 620               Dance Monkey                   Tones and I             1
# 407            Don't Start Now                      Dua Lipa             1
# 84   STAY (with Justin Bieber)  Justin Bieber, The Kid Laroi             2
# 693                  Seï¿½ï¿½o  Shawn Mendes, Camila Cabello             2
# 86           Someone You Loved                 Lewis Capaldi             1
# 127           Watermelon Sugar                  Harry Styles             1
# 162                  One Dance           Drake, WizKid, Kyla             3
# 14                   As It Was                  Harry Styles             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# ...
